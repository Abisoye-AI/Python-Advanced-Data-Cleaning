# %%
#import necessary libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### DATA LOADING PROCESS

# %% [markdown]
# # Import Data

# %%
#code to load data from directory
train=pd.read_csv('d_training_set.csv')
test=pd.read_csv('d_test_set.csv')

# %%
#this code is to view maximum columns without summarizing any column
pd.set_option('display.max_columns', None)
#code to load the train data
train.head()
# Out:
#    row_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0   30001      10000        10000          10000.0   36 months    7.89%
# 1   30002      27500        27500          27500.0   60 months    9.80%
# 2   30003      20000        20000          20000.0   36 months   14.46%
# 3   30004       2900         2900           2900.0   36 months   15.31%
# 4   30005       2400         2400           2400.0   36 months   18.99%
#
#    installment grade sub_grade           emp_title emp_length home_ownership  \
# 0       312.86     A        A5              Driver    9 years       MORTGAGE
# 1       581.60     B        B3   Branch Specialist  10+ years       MORTGAGE
# 2       688.03     C        C4         VP of Sales    7 years           RENT
# 3       100.98     C        C5  Operations Manager  10+ years       MORTGAGE
# 4        87.97     E        E1   Education Manager    2 years           RENT
#
#    annual_inc verification_status issue_d             purpose  \
# ...

# %%
#code to view information about the train dataset like the column type and number of non-null count
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103887 entries, 0 to 103886
# Data columns (total 93 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   row_id                          103887 non-null  int64
#  1   loan_amnt                       103887 non-null  int64
#  2   funded_amnt                     103887 non-null  int64
#  3   funded_amnt_inv                 103887 non-null  float64
#  4   term                            103887 non-null  object
#  5   int_rate                        103887 non-null  object
#  6   installment                     103887 non-null  float64
#  7   grade                           103887 non-null  object
#  8   sub_grade                       103887 non-null  object
#  9   emp_title                       96875 non-null   object
#  10  emp_length                      96906 non-null   object
#  11  home_ownership                  103887 non-null  object
# ...

# %%
#code to view test dataset
test.head()
# Out:
#    row_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0       1      15600        15600            15600   60 months    9.16%
# 1       2       2200         2200             2200   36 months    7.39%
# 2       3      10000        10000            10000   36 months    9.16%
# 3       4       8000         8000             8000   36 months    6.49%
# 4       5      17000        17000            17000   36 months    5.32%
#
#    installment grade sub_grade                  emp_title emp_length  \
# 0       325.05     B        B2     Senior sales assistant    2 years
# 1        68.33     A        A4                        NaN        NaN
# 2       318.75     B        B2  Digital Marketing Manager  10+ years
# 3       245.16     A        A2       Assistant Supervisor    6 years
# 4       511.96     A        A1            Project Manager    7 years
#
#   home_ownership  annual_inc verification_status issue_d             purpose  \
# ...

# %%
#code to view the data shape
print("Train Data shape: ",train.shape)
print("Test Data shape: ",test.shape)
# Out:
# Train Data shape:  (103887, 93)
# Test Data shape:  (15000, 92)

# %%
#code to view the statistical proerties of the train dataset.
train.describe()
# Out:
#               row_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  103887.000000  103887.000000  103887.000000    103887.000000
# mean    81944.000000   15581.702475   15581.702475     15574.323975
# std     29989.738045    8856.436183    8856.436183      8854.725240
# min     30001.000000    1000.000000    1000.000000       800.000000
# 25%     55972.500000    8400.000000    8400.000000      8400.000000
# 50%     81944.000000   14400.000000   14400.000000     14400.000000
# 75%    107915.500000   21000.000000   21000.000000     21000.000000
# max    133887.000000   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc            dti    delinq_2yrs  \
# count  103887.000000  1.038870e+05  103874.000000  103887.000000
# mean      460.558518  8.028415e+04      19.533214       0.344336
# std       261.449885  7.533659e+04       9.626113       0.907980
# min        30.120000  0.000000e+00      -1.000000       0.000000
# ...

# %%
#code to view columns with null values for train data
train.columns[train.isnull().any()].tolist()
# Out:
# ['emp_title',
#  'emp_length',
#  'title',
#  'dti',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'revol_util',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'bc_open_to_buy',
#  'bc_util',
#  'mo_sin_old_il_acct',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_tl_120dpd_2m',
#  'percent_bc_gt_75']

# %%
#code to view columns with null values for test data
test.columns[test.isnull().any()].tolist()
# Out:
# ['emp_title',
#  'emp_length',
#  'title',
#  'dti',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'revol_util',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'bc_open_to_buy',
#  'bc_util',
#  'mo_sin_old_il_acct',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_tl_120dpd_2m',
#  'percent_bc_gt_75']

# %% [markdown]
# ## DATA CLEANING PROCESS

# %%
#code to change 30months to 30 by using indexing to remove last parameter.(train data)
train['term'] = train['term'].map(lambda x: str(x)[:-3])

# %%
#code to change 30months to 30 by using indexing to remove last parameter.(test data)
test['term'] = test['term'].map(lambda x: str(x)[:-3])

# %%
#code to remove % sign in int_rate column for train data
train['int_rate'] = train['int_rate'].map(lambda x: str(x)[:-1])

# %%
#code to remove % sign in int_rate column for test data
test['int_rate'] = test['int_rate'].map(lambda x: str(x)[:-1])

# %%
#code to remove 'years' from the column in train data
train['emp_length'] = train['emp_length'].map(lambda x: str(x)[:1])

# %%
#code to remove 'years' from the column in test data
test['emp_length'] = test['emp_length'].map(lambda x: str(x)[:1])

# %%
#code to remove % sign in 'revol util' column for train data
train['revol_util'] = train['revol_util'].map(lambda x: str(x)[:-1])

# %%
#code to remove % sign in 'revol util' column for test data
test['revol_util'] = test['revol_util'].map(lambda x: str(x)[:-1])

# %%
#code to remove the + sign
train['emp_length'] = train['emp_length'].str.replace('+', ' ')

# %%
#code to remove the + sign
test['emp_length'] = test['emp_length'].str.replace('+', ' ')

# %%
#code to remove the '<' sign
train['emp_length'] = train['emp_length'].str.replace('<', ' ')

# %%
#code to remove the '<' sign
test['emp_length'] = test['emp_length'].str.replace('<', ' ')

# %%
#code to view all columns present in the train dataset as a list
train.columns
# Out:
# Index(['row_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
# ...

# %%
#code to view all columns present in the test dataset as a list
test.columns
# Out:
# Index(['row_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'application_type', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
# ...

# %%
# The main goal of this code  is to rename the different 
# class in our categorigal feature that were not properly named.
# or chanage the data type of the column for train data
cat_features ={"grade", "sub_grade", "emp_title", 
             "home_ownership","verification_status","purpose",
              "title","addr_state","initial_list_status","application_type","disbursement_method",'verification_status_joint'}

for cat_feature in cat_features:
    print (cat_feature, train[cat_feature].unique(), sep=":")
    print ("#"*50)
# Out:
# initial_list_status:['w' 'f']
# ##################################################
# verification_status:['Source Verified' 'Not Verified' 'Verified']
# ##################################################
# verification_status_joint:[nan 'Not Verified']
# ##################################################
# home_ownership:['MORTGAGE' 'RENT' 'OWN']
# ##################################################
# purpose:['debt_consolidation' 'other' 'medical' 'credit_card' 'home_improvement'
#  'car' 'major_purchase' 'small_business' 'moving' 'renewable_energy'
#  'vacation' 'house']
# ##################################################
# sub_grade:['A5' 'B3' 'C4' 'C5' 'E1' 'D4' 'C2' 'A3' 'E3' 'C1' 'E2' 'C3' 'A1' 'B4'
#  'D1' 'B5' 'A2' 'A4' 'D5' 'D3' 'B2' 'B1' 'F4' 'D2' 'E4' 'F1' 'G4' 'E5'
#  'G5' 'F2' 'F5' 'F3' 'G2' 'G1' 'G3']
# ##################################################
# addr_state:['CA' 'AL' 'TX' 'PA' 'FL' 'MO' 'UT' 'NE' 'WA' 'CT' 'IN' 'NC' 'MA' 'OR'
# ...

# %%
# The main goal of this code  is to rename the different 
# class in our categorigal feature that were not properly named.
# or chanage the data type of the column for test data
cat_features ={"grade", "sub_grade", "emp_title", 
             "home_ownership","verification_status","purpose",
              "title","addr_state","initial_list_status","application_type","disbursement_method",'verification_status_joint'}

for cat_feature in cat_features:
    print (cat_feature, test[cat_feature].unique(), sep=":")
    print ("#"*50)
# Out:
# initial_list_status:['w' 'f']
# ##################################################
# verification_status:['Source Verified' 'Verified' 'Not Verified']
# ##################################################
# verification_status_joint:[nan 'Not Verified']
# ##################################################
# home_ownership:['RENT' 'MORTGAGE' 'OWN']
# ##################################################
# purpose:['debt_consolidation' 'home_improvement' 'other' 'credit_card' 'car'
#  'house' 'major_purchase' 'medical' 'small_business' 'moving' 'vacation'
#  'renewable_energy']
# ##################################################
# sub_grade:['B2' 'A4' 'A2' 'A1' 'C2' 'B5' 'B4' 'E3' 'D2' 'B3' 'C5' 'A5' 'C3' 'B1'
#  'D4' 'E2' 'C1' 'D1' 'C4' 'E1' 'D5' 'D3' 'E4' 'A3' 'E5' 'F1' 'F2' 'F4'
#  'F5' 'G4' 'G2' 'G5' 'G1' 'F3' 'G3']
# ##################################################
# addr_state:['NJ' 'OR' 'PA' 'NY' 'CA' 'IL' 'IN' 'WI' 'GA' 'MN' 'TX' 'OH' 'MO' 'KY'
# ...

# %%
#Label encoding- so we can turn all categorical varialbles to numerial for train data
cat_features=["grade", "sub_grade", "emp_title", 
             "home_ownership","verification_status","purpose",
              "title","addr_state","initial_list_status","application_type","disbursement_method",'verification_status_joint']
             
for cat_feature in cat_features:
    train[f"{cat_feature}_cat"] = train[cat_feature].astype("category")
    train[f"{cat_feature}_cat"] = train[f"{cat_feature}_cat"].cat.codes

# %%
#Label encoding- so we can turn all categorical varialbles to numerial for test data
cat_features=["grade", "sub_grade", "emp_title", 
             "home_ownership","verification_status","purpose",
              "title","addr_state","initial_list_status","application_type","disbursement_method",'verification_status_joint']
             
for cat_feature in cat_features:
    test[f"{cat_feature}_cat"] = test[cat_feature].astype("category")
    test[f"{cat_feature}_cat"] = test[f"{cat_feature}_cat"].cat.codes

# %% [markdown]
# # Remove irrelevant data

# %%
#since the columns have been renamed by adding the subscrip'cat"
# we the drop the columsn which still act as categorical varaible for train data
train.drop(["grade", "sub_grade", "emp_title", 
             "home_ownership","verification_status","purpose",
              "title","addr_state","initial_list_status","application_type","disbursement_method",'verification_status_joint'], axis=1, inplace=True)
train.head()
# Out:
#    row_id  loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  \
# 0   30001      10000        10000          10000.0   36      7.89
# 1   30002      27500        27500          27500.0   60      9.80
# 2   30003      20000        20000          20000.0   36     14.46
# 3   30004       2900         2900           2900.0   36     15.31
# 4   30005       2400         2400           2400.0   36     18.99
#
#    installment emp_length  annual_inc issue_d    dti  delinq_2yrs  \
# 0       312.86          9     40000.0  Mar-16   5.34            1
# 1       581.60          1     55000.0  Jan-16   1.32            0
# 2       688.03          7    153000.0  Feb-16   9.64            0
# 3       100.98          1    105000.0  Mar-16  34.61            0
# 4        87.97          2     50000.0  Jan-16   1.80            0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0           Nov-06             0.0                    16.0
# ...

# %%
#since the columns have been renamed by adding the subscrip'cat"
# we the drop the columsn which still act as categorical varaible for test data
test.drop(["grade", "sub_grade", "emp_title", 
             "home_ownership","verification_status","purpose",
              "title","addr_state","initial_list_status","application_type","disbursement_method",'verification_status_joint'], axis=1, inplace=True)
test.head()
# Out:
#    row_id  loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  \
# 0       1      15600        15600            15600   60      9.16
# 1       2       2200         2200             2200   36      7.39
# 2       3      10000        10000            10000   36      9.16
# 3       4       8000         8000             8000   36      6.49
# 4       5      17000        17000            17000   36      5.32
#
#    installment emp_length  annual_inc issue_d    dti  delinq_2yrs  \
# 0       325.05          2     62000.0  Mar-16  16.80            0
# 1        68.33          n     13572.0  Feb-16  12.55            0
# 2       318.75          1    102500.0  Mar-16  20.43            3
# 3       245.16          6     55000.0  Jan-16  21.12            0
# 4       511.96          7    118500.0  Jan-16   7.52            0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0           Dec-06               0                     NaN
# ...

# %%
#view the columns again for train dataset
# and some visible changes from 'application_type_cat'
train.columns
# Out:
# Index(['row_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'int_rate', 'installment', 'emp_length', 'annual_inc', 'issue_d', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'annual_inc_joint', 'dti_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
# ...

# %% [markdown]
# # Filling missing Data

# %%
#this code is to fill null values using the fillna with median for train data
train[['emp_length', 'dti','inq_last_6mths','mths_since_last_record','mths_since_last_delinq','revol_util','mths_since_last_major_derog',
      'annual_inc_joint','dti_joint','open_acc_6m','open_act_il','open_il_12m','open_il_24m','mths_since_rcnt_il',
       'total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','inq_fi','total_cu_tl','bc_open_to_buy',
       'bc_util','mo_sin_old_il_acct','mths_since_recent_bc_dlq',
       'mths_since_recent_inq', 'mths_since_recent_revol_delinq','mths_since_recent_bc','num_tl_120dpd_2m','percent_bc_gt_75'
      ]] = train[['emp_length', 'dti','inq_last_6mths','mths_since_last_record','mths_since_last_delinq','revol_util','mths_since_last_major_derog',
      'annual_inc_joint','dti_joint','open_acc_6m','open_act_il','open_il_12m','open_il_24m','mths_since_rcnt_il',
       'total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','inq_fi','total_cu_tl','bc_open_to_buy',
       'bc_util','mo_sin_old_il_acct','mths_since_recent_bc_dlq',
       'mths_since_recent_inq', 'mths_since_recent_revol_delinq','mths_since_recent_bc','num_tl_120dpd_2m','percent_bc_gt_75']].fillna(
    train[['emp_length', 'dti','inq_last_6mths','mths_since_last_record','mths_since_last_delinq','revol_util','mths_since_last_major_derog',
      'annual_inc_joint','dti_joint','open_acc_6m','open_act_il','open_il_12m','open_il_24m','mths_since_rcnt_il',
       'total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','inq_fi','total_cu_tl','bc_open_to_buy',
       'bc_util','mo_sin_old_il_acct','mths_since_recent_bc_dlq',
       'mths_since_recent_inq', 'mths_since_recent_revol_delinq','mths_since_recent_bc','num_tl_120dpd_2m','percent_bc_gt_75']].median())

# %%
#filling the columns with null values
train[[ 'inq_last_12m']] = train[[ 'inq_last_12m']].fillna
(train[[ 'inq_last_12m']].median())
# Out:
# Series([], dtype: float64)

# %%
#this code is to fill nul values using the fillna with median for test data
test[['emp_length', 'dti','inq_last_6mths','mths_since_last_record','mths_since_last_delinq','revol_util','mths_since_last_major_derog',
      'annual_inc_joint','dti_joint','open_acc_6m','open_act_il','open_il_12m','open_il_24m','mths_since_rcnt_il',
       'total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','inq_fi','total_cu_tl','bc_open_to_buy',
       'bc_util','mo_sin_old_il_acct','mths_since_recent_bc_dlq',
       'mths_since_recent_inq', 'mths_since_recent_revol_delinq','mths_since_recent_bc','num_tl_120dpd_2m','percent_bc_gt_75','inq_last_12m'
      ]] = test[['emp_length', 'dti','inq_last_6mths','mths_since_last_record','mths_since_last_delinq','revol_util','mths_since_last_major_derog',
      'annual_inc_joint','dti_joint','open_acc_6m','open_act_il','open_il_12m','open_il_24m','mths_since_rcnt_il',
       'total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','inq_fi','total_cu_tl','bc_open_to_buy',
       'bc_util','mo_sin_old_il_acct','mths_since_recent_bc_dlq',
       'mths_since_recent_inq', 'mths_since_recent_revol_delinq','mths_since_recent_bc','num_tl_120dpd_2m','percent_bc_gt_75', 'inq_last_12m']].fillna(
    test[['emp_length', 'dti','inq_last_6mths','mths_since_last_record','mths_since_last_delinq','revol_util','mths_since_last_major_derog',
      'annual_inc_joint','dti_joint','open_acc_6m','open_act_il','open_il_12m','open_il_24m','mths_since_rcnt_il',
       'total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','inq_fi','total_cu_tl','bc_open_to_buy',
       'bc_util','mo_sin_old_il_acct','mths_since_recent_bc_dlq',
       'mths_since_recent_inq', 'mths_since_recent_revol_delinq','mths_since_recent_bc','num_tl_120dpd_2m','percent_bc_gt_75', 'inq_last_12m']].median())

# %%
#code to check if there is any other null columns for train data
train.columns[train.isnull().any()].tolist()
# Out:
# []

# %%
#code to check if there is any other null columns for test data
test.columns[test.isnull().any()].tolist()
# Out:
# []

# %% [markdown]
# # Dropping irrelevant columns

# %%
#drop unnecessary columns that could cause overfittimg during the training of models and also to avoid bias
#the columns with high duplicate values and columns with few parameters were also dropped for train data
train.drop(['emp_length', 'issue_d','delinq_2yrs','earliest_cr_line', 'mths_since_last_record',
           'collections_12_mths_ex_med', 'annual_inc_joint', 'dti_joint','acc_now_delinq',
           'inq_last_12m','inq_last_6mths','term','int_rate','revol_util'], axis=1, inplace=True)

# %%
#drop unnecessary columns that could cause overfittimg during the training of models and also to avoid bias
#the columns with high duplicate values and columns with few parameters were also dropped for test data
test.drop(['emp_length', 'issue_d','delinq_2yrs','earliest_cr_line', 'mths_since_last_record',
           'collections_12_mths_ex_med', 'annual_inc_joint', 'dti_joint','acc_now_delinq',
           'inq_last_12m','inq_last_6mths','term','int_rate','revol_util'], axis=1, inplace=True)

# %%
#visible changes in shape of the test and train data
print("Train Data shape: ",train.shape)
print("Test Data shape: ",test.shape)
# Out:
# Train Data shape:  (103887, 79)
# Test Data shape:  (15000, 78)

# %%
#viewing the train data to see that no categorical variable is present
train.head()
# Out:
#    row_id  loan_amnt  funded_amnt  funded_amnt_inv  installment  annual_inc  \
# 0   30001      10000        10000          10000.0       312.86     40000.0
# 1   30002      27500        27500          27500.0       581.60     55000.0
# 2   30003      20000        20000          20000.0       688.03    153000.0
# 3   30004       2900         2900           2900.0       100.98    105000.0
# 4   30005       2400         2400           2400.0        87.97     50000.0
#
#      dti  mths_since_last_delinq  open_acc  pub_rec  revol_bal  total_acc  \
# 0   5.34                    16.0         9        0       3226         14
# 1   1.32                    30.0        10        0       2839         33
# 2   9.64                    30.0         8        0      39772         11
# 3  34.61                    30.0        16        0      31875         41
# 4   1.80                    24.0        10        1       1400         69
#
# ...

# %%
#checking properties of the train column
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103887 entries, 0 to 103886
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   row_id                          103887 non-null  int64
#  1   loan_amnt                       103887 non-null  int64
#  2   funded_amnt                     103887 non-null  int64
#  3   funded_amnt_inv                 103887 non-null  float64
#  4   installment                     103887 non-null  float64
#  5   annual_inc                      103887 non-null  float64
#  6   dti                             103887 non-null  float64
#  7   mths_since_last_delinq          103887 non-null  float64
#  8   open_acc                        103887 non-null  int64
#  9   pub_rec                         103887 non-null  int64
#  10  revol_bal                       103887 non-null  int64
#  11  total_acc                       103887 non-null  int64
# ...

# %%
import pandas as pd
import numpy as np
import seaborn
import sklearn
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # DATA SEGMENTATION

# %%
#segmeting the data so it can be splitted using the train test split and also dropping the repaid_loan so the shape of 
#the train and test data can be equal
y = train["repaid_loan"]
X=train.drop("repaid_loan", axis =1)

# %%
#splitting the data and assigning 70% data for training and 30% for testing
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42, test_size=0.3)

# %%
#loading libraries for training
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %% [markdown]
# # LOADING DATA INTO LOGISTIC REGRESSION MODEL TO TRAIN

# %%
#fitting the data into the model
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#import libraries for training
import sklearn 
from sklearn.preprocessing import StandardScaler
import sklearn.model_selection as ms
from sklearn import preprocessing
import sklearn.metrics as sklm
from sklearn import linear_model
import numpy.random as nr

# %% [markdown]
# # EVALUATE YOUR MODEL

# %%
#code to view the various evaluation models for the prediction to see which performs better
def score_model(probs, threshold):
    return np.array([1 if x > threshold else 0 for x in probs[:,1]])

def print_metrics(labels, probs, threshold):
    scores = score_model(probs, threshold)
    metrics = sklm.precision_recall_fscore_support(labels, scores)
    conf = sklm.confusion_matrix(labels, scores)
    print('                 Confusion matrix')
    print('                 Score positive    Score negative')
    print('Actual positive    %6d' % conf[0,0] + '             %5d' % conf[0,1])
    print('Actual negative    %6d' % conf[1,0] + '             %5d' % conf[1,1])
    print('')
    print('Accuracy        %0.2f' % sklm.accuracy_score(labels, scores))
    print('AUC             %0.2f' % sklm.roc_auc_score(labels, probs[:,1]))
    print('Macro precision %0.2f' % float((float(metrics[0][0]) + float(metrics[0][1]))/2.0))
    print('Macro recall    %0.2f' % float((float(metrics[1][0]) + float(metrics[1][1]))/2.0))
    print(' ')
    print('           Positive      Negative')
    print('Num case   %6d' % metrics[3][0] + '        %6d' % metrics[3][1])
    print('Precision  %6.2f' % metrics[0][0] + '        %6.2f' % metrics[0][1])
    print('Recall     %6.2f' % metrics[1][0] + '        %6.2f' % metrics[1][1])
    print('F1         %6.2f' % metrics[2][0] + '        %6.2f' % metrics[2][1])
    
probabilities = logmodel.predict_proba(X_test)
print_metrics(y_test, probabilities, 0.5)
# Out:
#                  Confusion matrix
#                  Score positive    Score negative
# Actual positive         7              5659
# Actual negative         5             25496
#
# Accuracy        0.82
# AUC             0.60
# Macro precision 0.70
# Macro recall    0.50
#
#            Positive      Negative
# Num case     5666         25501
# Precision    0.58          0.82
# Recall       0.00          1.00
# F1           0.00          0.90

# %%
#code to view accuracy for test data
accuracy=logmodel.score(X_test,y_test)
print('accuracy=:'+str(accuracy))
# Out:
# accuracy=:0.8182693233227452

# %%
#code to view accuracy for train data
accuracy =logmodel.score(X_train,y_train)
print('accuracy ='+str(accuracy))
# Out:
# accuracy =0.8179042904290429

# %%
#code for prediction
prediction = logmodel.predict(X_train)
test_predict = logmodel.predict(X_test)

# %% [markdown]
# # USING GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
#using gradientboosting classifier with max_depth of 5
gbr=GradientBoostingClassifier (max_depth=5)
gbr.fit(X_train, y_train.ravel())
# Out:
# GradientBoostingClassifier(max_depth=5)

# %%
# prediction probability for the model
probabilities = gbr.predict_proba(X_test)
print_metrics( y_test, probabilities,0.5 )
# Out:
#                  Confusion matrix
#                  Score positive    Score negative
# Actual positive       287              5379
# Actual negative       285             25216
#
# Accuracy        0.82
# AUC             0.71
# Macro precision 0.66
# Macro recall    0.52
#
#            Positive      Negative
# Num case     5666         25501
# Precision    0.50          0.82
# Recall       0.05          0.99
# F1           0.09          0.90

# %%
solution=gbr.predict(test)
submission=pd.DataFrame({'row_id':test.row_id,'repaid_loan': solution})
submission.to_csv('GradientBoosting.csv', index=False)

# %%
#using randomforestclassifier

# %% [markdown]
# # USING LIGHTGBM

# %%
from lightgbm import LGBMClassifier

# %%
from xgboost import XGBClassifier

# %%
from sklearn.svm import SVC

# %%
rf = LGBMClassifier()
rf.fit(X_train,y_train)
# Out:
# LGBMClassifier()

# %%
y_prob = rf.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.
rf.score(X_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix=metrics.confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[  266,  5400],
#        [  249, 25252]], dtype=int64)

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.52      0.05      0.09      5666\n           1       0.82      0.99      0.90     25501\n\n    accuracy                           0.82     31167\n   macro avg       0.67      0.52      0.49     31167\nweighted avg       0.77      0.82      0.75     31167\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 0.5185911883219961

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.7127650829027655

# %%
#code to show the roc graph curve
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
probabilities = rf.predict_proba(X_test)
print_metrics( y_test, probabilities,0.5 )
# Out:
#                  Confusion matrix
#                  Score positive    Score negative
# Actual positive       266              5400
# Actual negative       249             25252
#
# Accuracy        0.82
# AUC             0.71
# Macro precision 0.67
# Macro recall    0.52
#
#            Positive      Negative
# Num case     5666         25501
# Precision    0.52          0.82
# Recall       0.05          0.99
# F1           0.09          0.90

# %%
solution=rf.predict(test)
submission=pd.DataFrame({'row_id':test.row_id,'repaid_loan': solution})
submission.to_csv('NEWSUB2.csv' ,sep=',' ,index=False)

# %%
#using neural network model

# %%
from sklearn.neural_network import MLPClassifier 

# Setting up a primitive (non-validated) model
mlpc = MLPClassifier(random_state = 0)# ANN model object created

mlpc.fit(X_train, y_train) # ANN model object fit
# Out:
# MLPClassifier(random_state=0)

# %%
y_pred = mlpc.predict(X_test) # model prediction process over test set

# %%
#loading libraries for training
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 0.5187687974086493

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.5187687974086493

# %%
#code to show the roc graph curve
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
def score_model(probs, threshold):
    return np.array([1 if x > threshold else 0 for x in probs[:,1]])

def print_metrics(labels, probs, threshold):
    scores = score_model(probs, threshold)
    metrics = sklm.precision_recall_fscore_support(labels, scores)
    conf = sklm.confusion_matrix(labels, scores)
    print('                 Confusion matrix')
    print('                 Score positive    Score negative')
    print('Actual positive    %6d' % conf[0,0] + '             %5d' % conf[0,1])
    print('Actual negative    %6d' % conf[1,0] + '             %5d' % conf[1,1])
    print('')
    print('Accuracy        %0.2f' % sklm.accuracy_score(labels, scores))
    print('AUC             %0.2f' % sklm.roc_auc_score(labels, probs[:,1]))
    print('Macro precision %0.2f' % float((float(metrics[0][0]) + float(metrics[0][1]))/2.0))
    print('Macro recall    %0.2f' % float((float(metrics[1][0]) + float(metrics[1][1]))/2.0))
    print(' ')
    print('           Positive      Negative')
    print('Num case   %6d' % metrics[3][0] + '        %6d' % metrics[3][1])
    print('Precision  %6.2f' % metrics[0][0] + '        %6.2f' % metrics[0][1])
    print('Recall     %6.2f' % metrics[1][0] + '        %6.2f' % metrics[1][1])
    print('F1         %6.2f' % metrics[2][0] + '        %6.2f' % metrics[2][1])
    
probabilities = mlpc.predict_proba(X_test)
print_metrics(y_test, probabilities, 0.5)
# Out:
#                  Confusion matrix
#                  Score positive    Score negative
# Actual positive      1057              4609
# Actual negative      3800             21701
#
# Accuracy        0.73
# AUC             0.52
# Macro precision 0.52
# Macro recall    0.52
#
#            Positive      Negative
# Num case     5666         25501
# Precision    0.22          0.82
# Recall       0.19          0.85
# F1           0.20          0.84

# %%
probabilities = mlpc.predict_proba(X_test)
print_metrics( y_test, probabilities,0.5 )
# Out:
#                  Confusion matrix
#                  Score positive    Score negative
# Actual positive      1057              4609
# Actual negative      3800             21701
#
# Accuracy        0.73
# AUC             0.52
# Macro precision 0.52
# Macro recall    0.52
#
#            Positive      Negative
# Num case     5666         25501
# Precision    0.22          0.82
# Recall       0.19          0.85
# F1           0.20          0.84

# %%
solution=mlpc.predict(test)
submission=pd.DataFrame({'row_id':test.row_id,'repaid_loan': solution})
submission.to_csv('NEURALNETWORKSUB.csv', index=False)

# %% [markdown]
# #  USING RANDOM FOREST CLASSIFIER

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_prob = rf.predict_proba(X_test)[:,1] # This will give you positive class prediction probabilities  
y_pred = np.where(y_prob > 0.5, 1, 0) # This will threshold the probabilities to give class predictions.
rf.score(X_test, y_pred)
# Out:
# 1.0

# %%
auc_roc=metrics.classification_report(y_test,y_pred)
auc_roc
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.48      0.03      0.06      5666\n           1       0.82      0.99      0.90     25501\n\n    accuracy                           0.82     31167\n   macro avg       0.65      0.51      0.48     31167\nweighted avg       0.76      0.82      0.75     31167\n'

# %%
auc_roc=metrics.roc_auc_score(y_test,y_pred)
auc_roc
# Out:
# 0.5125805265583945

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.6943561510907714

# %%
#code to show the roc graph curve
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
probabilities = rf.predict_proba(X_test)
print_metrics( y_test, probabilities,0.5 )
# Out:
#                  Confusion matrix
#                  Score positive    Score negative
# Actual positive       187              5479
# Actual negative       200             25301
#
# Accuracy        0.82
# AUC             0.69
# Macro precision 0.65
# Macro recall    0.51
#
#            Positive      Negative
# Num case     5666         25501
# Precision    0.48          0.82
# Recall       0.03          0.99
# F1           0.06          0.90

# %%
solution=rf.predict(test)
submission=pd.DataFrame({'row_id':test.row_id,'repaid_loan': solution})
submission.to_csv('RANDOMFORESTSUB.csv', index=False)
